# %% [markdown]
# ### Download, and Load the Libraries

# %%
# !pip install transformers
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
from transformers import BartTokenizer, BartForConditionalGeneration
import torch
import pandas as pd
from datasets import Dataset, DatasetDict

# %% [markdown]
# ### Load the Model/Tokenizer

# %%
# Retrieves a pre-trained tokenizer trained on the "bart-large-cnn" model
# The tokenizer is responsible for converting raw text into tokens
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')

# Instance of pre-trained BART model
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')

# Freeze all layers except last 2 layers

# Freeze all layers
for name, param in model.named_parameters():
    param.requires_grad = False

# Unfreeze last two layers in the encoder
unfrozen_params = list(model.model.encoder.layers[-2:].parameters())
for param in unfrozen_params:
    param.requires_grad = True

# Unfreeze last two layers in the decoder
unfrozen_decoder_params = list(model.model.decoder.layers[-2:].parameters())
for param in unfrozen_decoder_params:
    param.requires_grad = True
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
# Put the model on GPU if available.
if torch.cuda.is_available():
  model = model.to("cuda")

# %%
# Mounting files
import os
import pandas as pd
import random
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ###**Pre-processing InShorts data**
#
# 1. We use the raw Inshorts dataset which is a .csv file with 55,000+ rows to randomly create pr-dev-small.csv, pr-test-small.csv, pr-train-small.csv. Each csv contains a column for article and a column for summary.
#
# 2. train, test, development datasets are converted from .csv to pandas dataframes
#
# 3. Text processing the train, test and development datasets

# %%
## Load the Excel file into a pandas DataFrame
df = pd.read_excel("/gdrive/MyDrive/datasets/Inshorts_Cleaned_Data.xlsx")

# Keep only 'Headline' and 'Short' columns and discard remaining columns
df = df[['Headline', 'Short']]

# Count the total number of rows in the dataframe
num_rows = len(df)

# Randomly sample 50000 rows without replacement from the dataframe
df_sample = df.sample(n=5000, replace=False)

# Randomly allocate the 50000 rows into 3 different groups with the specified proportions
train_size = 3000
test_size = 1000
dev_size = 1000

train_set = df_sample.sample(n=train_size, replace=False)
df_sample = df_sample.drop(train_set.index)

test_set = df_sample.sample(n=test_size, replace=False)
dev_set = df_sample.drop(test_set.index)

# Export each group to a separate Excel file
train_set.to_excel('/gdrive/MyDrive/datasets/pr-train-small.xlsx', index=False)
test_set.to_excel('/gdrive/MyDrive/datasets/pr-test-small.xlsx', index=False)
dev_set.to_excel('/gdrive/MyDrive/datasets/pr-dev-small.xlsx', index=False)

# %%
# Read smaller sample datasets as Pandas dataframes
data_train = pd.read_excel('/gdrive/MyDrive/datasets/pr-train-small.xlsx')
data_train.head()
# Out:
#                                             Headline  \
# 0    Russia reveals plans to send cosmonauts to Mars
# 1   Sensex dips 465 points, Nifty down by 153 points
# 2  Cabinet nod to be sought for setting up ITIs i...
# 3       10 terrorists killed by Indian forces in Uri
# 4  Minister urges PM to bring back Udham Singh&#3...
#
#                                                Short
# 0  Russia recently announced that in 2018 it will...
# 1  The BSE Sensex on Thursday plunged 465.28 poin...
# 2  Skill Development and Entrepreneurship Ministr...
# 3  As many as 10 of the 15 terrorists trying to i...
# 4  Haryana state minister Karan Dev Kamboj has wr...

# %%
data_test = pd.read_excel('/gdrive/MyDrive/datasets/pr-test-small.xlsx')
data_test.head()
# Out:
#                                             Headline  \
# 0  Chennai restaurant introduces &#39;Donald Trum...
# 1  Europe&#39;s 1st space-based data satellite la...
# 2      Mathura clashes: SP died of brain haemorrhage
# 3  PM&#39;s step against black money a political ...
# 4  Bihar: 25 cops suspended over suspected hooch ...
#
#                                                Short
# 0  A photograph of a banner from casual dining re...
# 1  The first satellite of the European Space Agen...
# 2  Following the death of two police officers dur...
# 3  Following the demonetisation of ₹500 and ₹1,00...
# 4  As many as 25 policemen were suspended and six...

# %%
data_validate = pd.read_excel('/gdrive/MyDrive/datasets/pr-dev-small.xlsx')
data_validate.head()
# Out:
#                                             Headline  \
# 0   Grievance redressal system for Jaya constituency
# 1  Ibrahimović scored a 30-yard bicycle kick goal...
# 2  Mexico chefs make 216 feet long &#39;torta&#39...
# 3           Amul to sell camel milk in next 3 months
# 4    Political cartoonist Sudhir Tailang passes away
#
#                                                Short
# 0  In an effort to ensure faster grievance redres...
# 1  Ex-Sweden football team captain Zlatan Ibrahim...
# 2  Chefs and volunteers in Mexico City on Wednesd...
# 3  Dairy major Gujarat Cooperative Milk Marketing...
# 4  Renowned political cartoonist Sudhir Tailang, ...

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",

                           "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",

                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",

                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",

                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",

                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",

                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",

                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",

                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",

                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",

                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",

                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",

                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",

                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",

                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",

                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",

                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",

                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",

                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",

                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",

                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",

                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",

                           "you're": "you are", "you've": "you have"}

# %%
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = stopwords.words('english')

def preprocess(text):
    '''
    Returns a cleaned string called 'text'
    '''
    text = text.lower() # lowercase
    # convert have'nt -> have not
    text = text.split()
    for i in range(len(text)):
        word = text[i]
        if word in contraction_mapping:
            text[i] = contraction_mapping[word]
    # join entire text after contraction mapping is completed
    text = " ".join(text)
    text = text.split()
    newtext = []
    # create list of words after removing stopwords
    for word in text:
        if word not in stop_words:
            newtext.append(word)
    # create string of same words
    text = " ".join(newtext)
    text = text.replace("'s",'') # convert your's -> your
    text = re.sub(r'\(.*\)','',text) # remove (words inside a parenthesis)
    text = re.sub(r'[^a-zA-Z0-9. ]','',text) # remove punctuations
    text = re.sub(r'\.',' . ',text)
    return text

sample = "(hello) hi there .man tiger caller who's that isn't it ? WALL-E"
print(preprocess(sample))
# Out:
#  hi  . man tiger caller  walle
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Preprocess training data
data_train['Headline'] = data_train['Headline'].apply(lambda x:preprocess(x))
data_train['Short'] = data_train['Short'].apply(lambda x:preprocess(x))

# TRAINING DATA: instance of a dataset object from the datasets library
dataset_train = Dataset.from_pandas(data_train)

# Preprocess test data
data_test['Headline'] = data_test['Headline'].apply(lambda x:preprocess(x))
data_test['Short'] = data_test['Short'].apply(lambda x:preprocess(x))

# TEST DATA: instance of a dataset object from the datasets library
dataset_test = Dataset.from_pandas(data_test)

# Preprocess validation data
data_validate['Headline'] = data_validate['Headline'].apply(lambda x:preprocess(x))
data_validate['Short'] = data_validate['Short'].apply(lambda x:preprocess(x))

# VALIDATION DATA: instance of a dataset object from the datasets library
dataset_validate = Dataset.from_pandas(data_validate)

# %%
# Access the data within dataset_train using keys corresponding to the column names in data_train. 
# For example, dataset_train['Headline'] would give you the preprocessed headlines, and 
# dataset_train['Short'] would give you the preprocessed short texts
dataset_train[10]
# Out:
# {'Headline': 'syria39s aleppo slaughterhouse unhr chief',
#  'Short': 'un human rights chief zeid ra39ad alhussein friday said bombing syria39s aleppo constituted 34crimes historic proportions34 calling 34a slaughterhouse34 .  alhussein called involved conflict set aside 34political disagreements34 refer situation international criminal court .  comes russia extended ceasefire around aleppo 24 hours . '}

# %%
dataset_train['Headline'][:5]
# Out:
# ['russia reveals plans send cosmonauts mars',
#  'sensex dips 465 points nifty 153 points',
#  'cabinet nod sought setting itis 2500 blocks',
#  '10 terrorists killed indian forces uri',
#  'minister urges pm bring back udham singh39s pistol uk']

# %%
dataset_train['Short'][:5]
# Out:
# ['russia recently announced 2018 test nuclear engine could help cosmonauts reach mars six weeks compared 18 months spacecraft currently needs travel mars .  274 million project uses nuclear propulsion rockets weighs around half much chemical rocket without reducing thrust . ',
#  'bse sensex thursday plunged 465 . 28 points close 27827 . 53 nse nifty fell 153 . 90 points close 8591 . 25 .  fall came amid indian army confirming conducted 34surgical strikes34 pakistani territory wednesday night .  tcs top gainer adani ports sez major loser day . ',
#  'skill development entrepreneurship ministry soon seek approval cabinet establish industrial training institutes  2500 blocks country union minister rajiv pratap rudy said wednesday .  pointing disparity courses offered itis said nearly 61 students going itis trained two trades despite 127 trades . ',
#  'many 10 15 terrorists trying infiltrate indian side pakistan killed tuesday indian security forces jammu kashmir39s lachipura area uri sector .  terrorists initiated firing area indian forces reportedly retaliated full might operation still underway . ',
#  'haryana state minister karan dev kamboj written prime minister narendra modi urging bring back shaheed udham singh39s pistol book concealed shooting michael o39dwyer london .  kamboj said book pistol could kept museum inspire youth future generations . ']

# %% [markdown]
# ### Prepare The Dataset
# Writing a function to handle the tokenization and change the format of the data to an acceptable structure for the model. The dataset by default has Short, and Headline columns that needed to be changed to input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, labels using the set_format() function.

# %%
short_length=512
headline_length=64

def process_data_to_model_inputs(batch):
  '''
  Takes a data batch (a dictionary) as input and processes it to create model inputs
  to return an updated batch (a dictionary)
  '''
  # Tokenize the inputs and labels by splitting the text into tokens and encoding them
  # inputs = instance of tokenizer() object -- for Article/"Short"
  # outputs = instance of tokenizer() object -- for Summary/"Headline"
  inputs = tokenizer(batch["Short"], padding="max_length", truncation=True, max_length=short_length)
  outputs = tokenizer(batch["Headline"], padding="max_length", truncation=True, max_length=headline_length)

  # Update batch dictionary with new keys, with values assigned from inputs object's attributes
  # and outputs object's attributes
  batch["input_ids"] = inputs.input_ids
  batch["attention_mask"] = inputs.attention_mask
  batch["decoder_input_ids"] = outputs.input_ids
  batch["decoder_attention_mask"] = outputs.attention_mask
  batch["labels"] = outputs.input_ids.copy()

  # We have to make sure that the PAD token is ignored for calculating the loss
  # Replacing the PAD token IDs with -100, a special value that indicates they should be ignored during training
  batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] for labels in batch["labels"]]

  return batch

# %%
# Train data
# Returns a transformed instance of DatasetDict class for dataset_train instance by applying
# process_data_to_model_inputs() function

dataset_train_dict = dataset_train.map(
    process_data_to_model_inputs, 
    batched=True,
    remove_columns=["Short", "Headline"]
)

dataset_train_dict.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids",
                           "decoder_attention_mask", "labels"],
)

# Validation data
# Returns a transformed instance of DatasetDict class for dataset_validate instance by applying
# process_data_to_model_inputs() function

dataset_validate_dict = dataset_validate.map(
    process_data_to_model_inputs, 
    batched=True,
    remove_columns=["Short", "Headline"]
)

dataset_validate_dict.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids",
                           "decoder_attention_mask", "labels"],
)

# Test data
# Returns a transformed instance of DatasetDict class for dataset_test instance by applying
# process_data_to_model_inputs() function

dataset_test_dict = dataset_test.map(
    process_data_to_model_inputs, 
    batched=True,
    remove_columns=["Short", "Headline"]
)

dataset_test_dict.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids",
                           "decoder_attention_mask", "labels"],
)
# Out:
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
dataset_train_dict[0]

# %% [markdown]
# Based on the provided `process_data_to_model_inputs` function, the output of `dataset_train_dict[0]` will be a dictionary-like object containing the processed example at index 0 of the "train" split.
#
# The output dictionary will have the following keys and values:
#
# - `"input_ids"`: A list of token IDs representing the tokenized and encoded "Short" text sequence, with a maximum length of 512 tokens after padding or truncation.
# - `"attention_mask"`: A list of binary values indicating which tokens in the "Short" text sequence should be attended to (1) and which ones should be ignored (0) during model training or inference.
# - `"decoder_input_ids"`: A list of token IDs representing the tokenized and encoded "Headline" text sequence, with a maximum length of 64 tokens after padding or truncation.
# - `"decoder_attention_mask"`: A list of binary values indicating which tokens in the "Headline" text sequence should be attended to (1) and which ones should be ignored (0) during model training or inference.
# - `"labels"`: A list of token IDs representing the encoded "Headline" text sequence, with the same maximum length as `"decoder_input_ids"`. This serves as the target labels for the model's training.
#
# The `"labels"` are adjusted to ignore the padding tokens by replacing them with `-100` to ensure they are not considered in the loss calculation.
#
# Overall, `dataset_train_dict[0]` will contain the processed example with the input and target information necessary for training the model.

# %% [markdown]
# The dataset is not batched yet. We can use PyTorch's DataLoader function to take care of batching the data. Consider using a larger batch_size if you do not have hardware limitation.

# %%
from torch.utils.data import DataLoader

batch_size      = 10
# Instantiate dataloader objects for train, test, validation
train_data      = DataLoader(dataset_train_dict, batch_size=batch_size)
validation_data = DataLoader(dataset_validate_dict, batch_size=batch_size)
test_data = DataLoader(dataset_test_dict, batch_size=batch_size)

# %%
first_element = next(iter(train_data))
print(first_element)

# %% [markdown]
# ### Loss function

# %%
from torch.nn import CrossEntropyLoss
loss_fct = CrossEntropyLoss()

# %% [markdown]
# ### Optimizer

# %%
from transformers import AdamW
optimizer = AdamW(model.parameters(), lr=5e-4)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %% [markdown]
# ### Learning Rate Scheduler
#
# - The learning rate scheduler adjusts the learning rate during training to optimize the model's performance.
# - A linear scheduler increases the learning rate linearly over the training steps.
# - The num_warmup_steps and num_training_steps help determine the learning rate schedule.
# - The lr_scheduler object can be used during model training to update the learning rate based on the schedule.

# %%
from transformers import get_scheduler

num_epochs = 10
num_training_steps = num_epochs * len(train_data)
num_validation_steps = num_epochs * len(validation_data)

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps
)

# %% [markdown]
# ### Encoder, Decoder, Last Linear Layer

# %% [markdown]
# The encoder component of the `BartForConditionalGeneration` model is called. We will use it to process input sequences and extract their contextual representations.
#
# `the_encoder` is an instance of the `BartEncoder` class, which is composed of multiple layers of self-attention and feed-forward neural networks.
#
# The `BartEncoder` class typically contains the following key attributes:
#
# - `embed_tokens`: The embedding layer that maps input tokens to continuous representations.
# - `encoder`: A stack of Transformer encoder layers that process the input sequence and generate contextual representations.
# - `embed_positions`: Positional embeddings that encode the position information of the input tokens.
# - `layernorm_embedding`: A layer normalization module applied to the output of the embedding layer.
# - `layer_norm`: A layer normalization module applied to the output of each encoder layer.

# %%
# accessing the modified model object's encoder which has last 2 layers unfrozen
the_encoder = model.model.encoder

# %% [markdown]
# The decoder component of the `BartForConditionalGeneration` model is called.  We use it to generate output sequences, conditioned on the contextual representations. This is done in autoregressive manner, where the decoder generates tokens one at a time, taking into account the previously generated tokens.
#
# The decoder is designed to take the encoder's contextual representations as input and produce the output sequence step by step.
#
# `the_decoder` object is typically an instance of the `BartDecoder` class. The `BartDecoder` class typically contains the following key attributes:
#
# - `embed_tokens`: The embedding layer that maps output tokens to continuous representations.
# - `decoder`: A stack of Transformer decoder layers that generate the output sequence based on the contextual representations from the encoder.
# - `embed_positions`: Positional embeddings that encode the position information of the output tokens.
# - `layernorm_embedding`: A layer normalization module applied to the output of the embedding layer.
# - `layer_norm`: A layer normalization module applied to the output of each decoder layer.

# %%
# accessing the modified model object's decoder which has last 2 layers unfrozen
the_decoder = model.model.decoder

# %% [markdown]
# `last_linear_layer` is an instance of a linear layer that performs a linear transformation on the input data. the `last_linear_layer` is an instance of the `torch.nn.Linear` class.
#
# The attribute `lm_head` refers to the last linear layer of the model, which is responsible for generating the output logits or scores for each token in the output sequence.
#
# The last linear layer is typically a linear transformation that takes the contextual representations from the decoder and maps them to the vocabulary space. It essentially serves as a language model head, providing probabilities or scores for each token in the vocabulary, indicating the likelihood of that token being the next token in the generated sequence.
#
# We can use the last linear layer to generate the output logits or scores for each token in the output sequence. These logits can then be used for various purposes, such as calculating the loss, generating the next token using sampling or beam search, or evaluating the model's performance.
#
# The `torch.nn.Linear` class represents a linear transformation that maps an input tensor of shape `(batch_size, input_size)` to an output tensor of shape `(batch_size, output_size)` through a matrix multiplication followed by a bias addition.
#
# The `torch.nn.Linear` class typically contains the following key attributes:
#
# - `weight`: The weight matrix of shape `(output_size, input_size)` that is used for the linear transformation.
# - `bias`: The bias vector of shape `(output_size)` that is added to the output of the linear transformation.

# %%
last_linear_layer = model.lm_head

# %% [markdown]
# ### Training + Validation Loop

# %%
from tqdm.auto import tqdm
progress_bar = tqdm(range(num_training_steps + num_validation_steps))
val_losses = []

for epoch in range(num_epochs):
    # The Training Loop for One Epoch
    model.train()
    training_loss = 0.0
    validation_loss = 0.0
    print("Training...")
    for batch in train_data:
        if torch.cuda.is_available():
          # k = input_id, v = tensor for input_id
          # k = attention_mask, v = tensor for attention_mask
          # k  = decoder_input_ids, v = tensort ...
          batch = {k: v.to('cuda') for k, v in batch.items()}

        encoder_output = the_encoder(input_ids = batch['input_ids'],
                                    attention_mask = batch['attention_mask'])
        
        decoder_output = the_decoder(input_ids=batch['decoder_input_ids'],
                                    attention_mask=batch['decoder_attention_mask'],
                                    encoder_hidden_states=encoder_output[0],
                                    encoder_attention_mask=batch['attention_mask'])

        decoder_output = decoder_output.last_hidden_state
        lm_head_output = last_linear_layer(decoder_output)

        loss = loss_fct(lm_head_output.view(-1, model.config.vocab_size),
                        batch['labels'].view(-1))
        training_loss += loss.item()

        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
    
    # Evaluate the Model performance on Validation set
    # after the 1 epoch Training.
    model.eval()
    print("Validating...")
    for batch in validation_data:
        if torch.cuda.is_available():
          batch = {k: v.to('cuda') for k, v in batch.items()}
        
        with torch.no_grad():
            outputs = model(**batch)

        loss = outputs.loss
        validation_loss += loss
        progress_bar.update(1)
    
    training_loss = training_loss / len( train_data )
    validation_loss = validation_loss / len( validation_data )
    print("Epoch {}:\tTraining Loss {:.2f}\t/\tValidation Loss {:.2f}".format(epoch+1, training_loss, validation_loss))
    val_losses.append(validation_loss)
    if validation_loss <= min(val_losses):
        torch.save(model.state_dict(), "/gdrive/MyDrive/AML/FinalProject/Best_BART_V2.pt")
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]
# Training...
# Validating...
# Epoch 1:	Training Loss 1.14	/	Validation Loss 0.05
# Training...
# Validating...
# Epoch 2:	Training Loss 0.05	/	Validation Loss 0.05
# Training...
# Validating...
# Epoch 3:	Training Loss 0.03	/	Validation Loss 0.04
# Training...
# Validating...
# Epoch 4:	Training Loss 0.02	/	Validation Loss 0.03
# Training...
# Validating...
# Epoch 5:	Training Loss 0.01	/	Validation Loss 0.02
# Training...
# Validating...
# Epoch 6:	Training Loss 0.01	/	Validation Loss 0.02
# Training...
# Validating...
# Epoch 7:	Training Loss 0.00	/	Validation Loss 0.03
# Training...
# Validating...
# Epoch 8:	Training Loss 0.01	/	Validation Loss 0.01
# Training...
# Validating...
# Epoch 9:	Training Loss 0.01	/	Validation Loss 0.01
# Training...
# Validating...
# Epoch 10:	Training Loss 0.00	/	Validation Loss 0.01

# %% [markdown]
# ### Observing the outputs

# %%
from tqdm.auto import tqdm

# Instance of pre-trained BART model
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')
# Load the trained model
model.load_state_dict(torch.load("/gdrive/MyDrive/AML/FinalProject/Best_BART_V2.pt"))
if torch.cuda.is_available():
    model.cuda()
# Set the model to evaluation mode:
model.eval()
predictions = []

# Iterate over the test_dataset and generate predictions using the model:
with tqdm(total=len(test_data), desc="Generating Predictions") as progress_bar:
    for batch in test_data:
        if torch.cuda.is_available():
            batch = {k: v.to('cuda') for k, v in batch.items()}

        with torch.no_grad():
            outputs = model.generate(
                input_ids=batch["input_ids"],
                attention_mask=batch["attention_mask"],
                max_length=headline_length,
                num_beams=4,
                early_stopping=True
            )

        # Convert the generated output ids back to text
        generated_headlines = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        predictions.extend(generated_headlines)

        progress_bar.update(1)

# Get the actual headlines from data_test
actual_headlines = data_test["Headline"]
# Out:
# Generating Predictions:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# Compare the predictions with actual headlines
for prediction, actual in zip(predictions, actual_headlines):
    print("Prediction:", prediction)
    print("Actual:", actual)
    print()
# Out:
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottonotnotbutnotthethehownottobutnotbutbuttonot
# Actual: chennai restaurant introduces 39donald trump white dosa39
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now currently also not now currently actually
# Actual: europe39s 1st spacebased data satellite launched
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhenbutbutandandbutbutaccordingaccordingaccordingbutnotevenevenbutbuteveneveneventhethebutnottobutnotyetyetyetnotnoteventhenotnot
# Actual: mathura clashes sp died brain haemorrhage
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottonotnotbutnotthethehownottobutnotbutbuttonot
# Actual: pm39s step black money political gimmick sarkar
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhenbutbutandandbutbutaccordingaccordingaccordingbutnotevenevenbutbuteveneveneventhethebutnottobutnotyetyetyetnotnotevenyetyettoo
# Actual: bihar 25 cops suspended suspected hooch tragedy
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: hollywood pays tribute star trek actor anton
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: 20000 mexicans protest trump39s border wall
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenoteventhethebutnottonotevennottothenotnotununnotnotgetgetget get get
# Actual: argentina football coach gerardo martino resigns
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: restored last supper renaissance painting unveiled
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: jennifer lopez endorses hillary clinton us president
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: trial run indias first 700 mw nuclear reactor 2017
#
# Prediction:  a a a an an an a a to to to and and and to and to to but not not to to not not not NOT NOT NOT not NOT not not unt unt unt nont nont nont antit antit antit multit multit multit subt subt subt multit multit nont nont subt subt antit antit nont nont multit
# Actual: esellers claim 300 cr risk snapdeal39s unpaid dues
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: dhoni biopic poster released 35th bday
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnoteveneveneven even even even right right now right now now here now here here here today today today here today here here again here here right now here today again here again again here today
# Actual: brazilian surfer spins 540 degrees midair championship
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottobutnotthethehownotnotbutnottootototootootoo
# Actual: man makes parody mark zuckerberg39s post wife
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottobutnottotonoteventotothethebutnotthethehownotnotbutnottootototootootoo
# Actual: taliban kill sikh opposition leader pakistan
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: 1986 team better messis lot maradona
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently actually now currently also now currently
# Actual: euro may exist 10 yrs former french economy minister
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: stairs eiffel tower sold 3 . 8 crore
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: oxford dictionary adds 39moobs39 39yolo39
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnoteveneveneventhethebutnoteventhenotnottotothethenoteventotonotnotthetheyouyouyouyouryouryourmanymanymany
# Actual: reprising karisma rambha39s role judwaa 2 taapsee
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: cbi case shock hit airline hard air india chairman
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: passports bad habit getting lost sushma swaraj
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: hyundai motors39 2015 profit hits 5year low
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: nzs latham given despite catch
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: next spectrum auction likely mayjune
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: panasonic president asks employees leave office 8 pm
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: ed sheeran releases two new songs
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottotonotevenbutnotthethebutnottobutnotbutnottootootootototootoobutbuttoto
# Actual: amitabh bachchan crosses 20 mn twitter followers
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: terrorists open fire crpf jawans jampk 1 injured
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: bihar ssc answers leaked whatsapp report
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: bengaluru cancels david guetta39s show scheduled tonight
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: twoyrold saves twin brother dresser falls
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: lose something gain something bjp mp queue deaths
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently actually now currently also now currently
# Actual: new tb diagnostic tool likely year icmr
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: annual hair freezing contest held canada
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottotonoteventotothethebutnottothenottonottobutnotbutnotthethehownotnotbut
# Actual: rafael nadal wins gold men39s doubles
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttotoununnotevenbutnotununun
# Actual: mary kom swamy take oath rs members
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottotonoteventotothethebutnottothenottonottobutnotbutnotthethehownotnotbut
# Actual: bjp nominate goyal prabhu rs elections
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: us voter turnout 20yr low presidential elections
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotandnotnoteveneveneven even even even right right now right now now now that there is now now not even even still not even now now actually still not not not actually not not
# Actual: startup builds fullyautomated smart homes
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottobutnotthethehownotnotbutnottootototootootoo
# Actual: google censor 39pied piper jihad39 reports
#
# Prediction: , and other other other many other many many many several several several many many other several several different different different various different different other other various other various different other various various various other different different certain certain certain various various different various various certain certain specific specific specific certain specific certain certain different different specific specific different
# Actual: cadbury forced explain false claims 39halal39 chocolate
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: kohli must listen keeper taking drs ganguly
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billions billion billion billion billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions million billion billions millions million millions million billions billions trillions trillions trillions billions billions thousands millions billions billion billions trillions billions
# Actual: 39girls character length skirt39
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhenbutbutandandbutbutaccordingaccordingaccordingbutnotevenevenbutbuteveneveneventhethebutnottobutnotyetyetyetnotnotevenyetyettoo
# Actual: wikileaks threatens sue cnn comments assange
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttotoununnotevenbutnotununun
# Actual: pak captain ali fined 100 match fees slow overrate
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottobutnottotonotnotbutnotthethehownottonoteventotothethebutnottootootooto
# Actual: 39sairat39 becomes highest grossing marathi film
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: throwing away money won39t make someone win flipkart ceo
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnoteveneveneventhethebutnoteventhenotnottotothethenoteventotonotnotthetheyouyouyouyouryouryourmanymanymany
# Actual: bodybuilder 39almost dies39 getting bit ladybird
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now currently also not now currently actually
# Actual: gujarat defeat mumbai move ipl playoffs
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: allow mother tongue civil services main exam cpi
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottobutnotthethehownotnotbutnottootototootootoo
# Actual: yumist shuts bengaluru expands ncr
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnoteveneveneventhethebutnoteventhenotnottotothethenotevenbutnottothenottobutnotthethehownottonotnot
# Actual: panel clears 3 new airports39 construction andhra
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now right now now here here here today here here right now here right here here again here right away here here also there here here now here again right here right
# Actual: tesla looking raise 1 . 15 billion fund model 3
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: emunicipality building come rajasthan
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: scientists search leonardo da vinci39s dna
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: idea cellular net profit 38 . 9 576 cr
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: want cast ajay kajol family drama rohit
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnoteveneveneventhethebutnoteventhenotnottotothethenoteventotonotnotthetheyouyouyouyouryouryourmanymanymany
# Actual: jayalalithaa seeks exemption tn neet
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: embassy group buys 73 . 4 stake le meridien bengaluru
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: woman driver us makes longest ever uber ride
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: man united tops table fouls committed
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnoteveneveneven even even even right right now right now now here now here here here today today today here today here here again here here right now here today again here again again here today
# Actual: 47th international film festival india begins goa
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottotonoteventotothethebutnottothenottonottobutnotbutnotthethehownotnotbut
# Actual: tharoor detained protesting note ban kerala
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: demonetisation may push credit banks cii
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotandnotnoteveneveneven even even even right right now right now now now that there is now now not even even still not even now now actually still not not not actually not not
# Actual: jaish militant arrested baramulla jampk
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottonotnotbutnotthethehownottobutnotbutbuttonot
# Actual: sc dismisses pil seeking probe sahara birla it raids
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: 2nd green revolution needs reforms niti aayog
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billions billion billion billion billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions million billion billions millions million millions million billions billions trillions trillions trillions billions billions thousands millions billions billion billions trillions billions
# Actual: souvenir store sells 39polluted39 beijing air cans
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: tv rights 39baahubali 239 sold 51 cr reports
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: million gamers uk spent money pokmon go
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: agents charge 5k enps subscribers
#
# Prediction:  a a a an an an a a to to to and and and to and to to but but not not not even even even to not even to but not even not not to not not NOT NOT NOT not NOT not not unt unt unt Unt unt unt ut ut ut Ut Ut Ut ut ut
# Actual: broad 4th player bat 11 100th test
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: set halfway homes mentally ill prisoners urgently hc
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: teaser s3 gets 2 million views less 24 hours
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottobutnotthethehownotnotbutnottootototootootoo
# Actual: srk interacts india39s 1st transgender band
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: tata motors profit dips 57 2236 cr q1
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: prabhas 1st south indian actor feature madame tussauds
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: mukesh ambani india39s richest person forbes
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: cricket australia charges india39s harmanpreet misconduct
#
# Prediction: , and other other other many other many many many several several several many many other several several different different different various different different other other various other various different other various various various other different different certain certain certain various various different various various certain certain specific specific specific certain specific certain certain different different specific specific different
# Actual: awards don39t define stardom sonam kapoor
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenoteventhethebutnottonotevennottothenotnotununnotnotgetgetgetgivegive
# Actual: celebrities passed away 2016
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: delhi police overstaffed high court
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: advani slams govt opposition parliament logjam
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: fossil suggests dinosaurs made honking sounds
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: augmented reality big idea like smartphone tim cook
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhenbutbutandandbutbutaccordingaccordingaccordingbutnotevenevenbutbuteveneveneventhethebutnottobutnotyetyetyetnotnoteventhenotnot
# Actual: mcc stick current ball tampering rules
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: makeup artist launches genderneutral eyeshadow palette
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttonotevenbutnottoonotnotununun
# Actual: mobikwik help water bill payments delhi
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottonotnotbutnotthethehownottobutnotbutbuttonot
# Actual: hindu outfit celebrates trump39s victory
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: goa launches duck boats run land water
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: navapur railway station located two indian states
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottotonotevenbutnotthethebutnottobutnotbutnottootootootototootoobutbuttoto
# Actual: israel frees 12yearold palestinian prisoner
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnoteveneveneventhethebutnoteventhenotnottotothethenoteventotonotnotthetheyouyouyouyouryouryourmanymanymany
# Actual: 14 yr old boy wins international maths contest
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: karnataka govt give stipend tribal students
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotbutnottootootootototootoobutbuttoto
# Actual: syrian rebel bloc offers power sharing govt
#
# Prediction:  a a a an an an a a to to to and and and to and to to but not not to to not not not NOT NOT NOT not NOT not not unt unt unt nont nont nont antit antit antit multit multit multit subt subt subt multit multit nont nont subt subt antit antit nont nont multit
# Actual: govt respect human lives ngt
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: floods killed 300 people india year
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: hazard39s double gives chelsea 41 win
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: govt import additional 90k tonnes pulses
#
# Prediction:  a a a an an an a a to to to and and and to and to to but but not not not even even even to to or even even just to not even to not to to not not to not NOT not not NOT NOT NOTNOTNOTNOT NOT NOT UN UN un un un
# Actual: militants families same mehbooba mufti
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: video explains snapchat filters work
#
# Prediction:  a a a an an an a a to to to and and and to and to to but not not to to not not not NOT NOT NOT not NOT not not unt unt unt nont nont nont antit antit antit multit multit multit subt subt subt multit multit nont nont subt subt antit antit nont nont multit
# Actual: wanted poster issued weatherman snow forecast flops
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: isro launch 6th irnss satellite march 10
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: turkey lowest hotel occupancy europe 3916 report
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: trump39s son breaks law sharing photo filled ballot
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: sc declines pakistani national39s plea visa extension
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: pilot offers free flight sick people39s treatment
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottobutnotthethehownotnotbutnottootototootootoo
# Actual: men identify transformer faces better women
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotevenevenevennotnottotonotevenbutnoteventotothethenotevennottonottobutnottothenotnotununnotnot
# Actual: srk akshay forbes39 highest paid actors list
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottobutnottotonoteventotothethebutnotthethehownotnotbutnottootototootootoo
# Actual: pv sindhu reaches semifinals hong kong open
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnoteveneveneventhethebutnoteventhenotnottotothethenoteventotonotnotthetheyouyouyouyouryouryourmanymanymany
# Actual: vidya work rajinikanth kabali spinoff reports
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: cocaine worth 1200 crore seized indiabound ship
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottobutnotthethehownotnotbutnottootototootootoo
# Actual: three jawans martyred one mutilated pak action
#
# Prediction: , and other other other many other other more more more less less less more more most more more mostly more mostly mostly mostly most mostly mostly definitely definitely not definitely certainly definitely definitely definitely certainly certainly certainly definitely certainly not definitely definitely probably definitely definitely considerably considerably considerably possibly possibly possibly actually possibly possibly definitely definitely possibly possibly
# Actual: man smashes iphones apple store france
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: world39s first selfie taken 1839
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottobutnottotonoteventotothethebutnotthethehownotnotbutnottootototootootoo
# Actual: pak seeks clarification us strike soil
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: sc hear plea impose governor39s rule jampk
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: 3 bulandshahr gangrape accused sent custody
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttonotevenbutnotthethehownottonot
# Actual: experts discover two 39cavities39 egypt39s great pyramid
#
# Prediction:  a a a an an an a a to to to and and and to and to to but not not to to not not not NOT NOT NOT not NOT not not unt unt unt nont nont nont antit antit antit multit multit multit subt subt subt multit multit nont nont subt subt antit antit nont nont multit
# Actual: rupinder scores six goals india39s 102 rout japan
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhenbutbutandandbutbutaccordingaccordingaccordingbutnotevenevenbutbuteveneveneventhethebutnottobutnotyetyetyetnotnotevenyetyettoo
# Actual: hindus cannot live freely parts india mohan bhagwat
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now right now now here here here today here here right now here right here here again here right away here here also there here here now here again right here right
# Actual: icici bank cuts home loan rate 0 . 15
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttonoteventhethehownotnotthethebut
# Actual: former greece goalkeeper mentoring refugee football team
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: fur collected tax 17th century serbia
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: man utd held 11 draw arsenal39s late strike
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: italy host hideandseek world championship
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: indian record performing yoga motorcycle
#
# Prediction:  a a a an an an a a the the the an an ar ar ar Ar ar ar arch arch arch Arch Arch Arch arch archArchArchArcharcharcharchArch Arch ArchArcharchArchArch ArchArchArch arch archarcharcharthartharthathathatharthatharthartharcharch
# Actual: sehwag tweets birthday wishes virat kohli
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnoteveneveneven even even even right right now right now now here now here here here today today today here today here here again here here right now here today again here again again here today
# Actual: sector growth stabilise 1113 moody39s
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotbutnottootootootototootoobutbuttoto
# Actual: blast somalia kills 18 mogadishu marketplace
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: ed seeks revocation vijay mallya39s passport
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottonotnotbutnotthethehownottobutnotbutbuttonot
# Actual: income tax return filing date extended aug 5
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottobutnotthethehownotnotbutnottootototootootoo
# Actual: eu awards 2 exisis sex slaves top human rights prize
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: team hacked tesla breaks nexus 6p 20 mins
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottotonotevenbutnotthethebutnottobutnotbutnottootootootototootoobutbuttoto
# Actual: nifty 50 companies39 net profit grow 6 q2 report
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: artists imagine az future trump elected us prez
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttonotevenbutnotthethehownottonot
# Actual: pakistan army school massacre mastermind killed
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottobutnotthethehownotnotbutnottootototootootoo
# Actual: state minorities wb 39inadequate39 jaitley
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotandnotnoteveneveneven even even even right right now right now now now that there is now now not even even still not even now now actually still not actually not not not actually
# Actual: apple considered building cybercafes instead stores
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now right now now here here here today here here right now here right here here again here right away here here also there here here now here again right here right
# Actual: iphone 7 plus 39out stock39 india short supply
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: microsoft make windows 10 update 35 smaller
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: asked mistry step tata chemicals chairman bhat
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotbutnottootootootototootoobutbuttoto
# Actual: 8 mous inked indiasouth africa ceos forum
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: outfits made assam39s muga silk presented fashion week
#
# Prediction:  a a a an an an a a to to to and and and to and to to but not not to to not not not NOT NOT NOT not NOT not not unt unt unt nont nont nont antit antit antit multit multit multit subt subt subt multit multit nont nont subt subt antit antit nont nont multit
# Actual: welspun faces new probe another us retailer
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottobutnottotonoteventotothethebutnotthethehownotnotbutnottootototootootoo
# Actual: sachin dravid made odi39s highest stand nov 8 1999
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttonotevenbutnottoonotnotununun
# Actual: samajwadi party using muslims like tejpatta biryani bsp
#
# ...
# Actual: we39re placing bandaids there39s cancer murthy
#
# Prediction:  a a a an an an a a to to to and and and to and to to but not not to to not not not NOT NOT NOT not NOT not not unt unt unt nont nont nont antit antit antit multit multit multit subt subt subt multit multit nont nont subt subt antit antit nont nont multit
# Actual: baloch leader file case icj musharraf
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: delhi govt launches drug abuse prevention campaign youth
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttonoteventhethehownotnotthethebut
# Actual: federer nadal inaugurate rafa39s academy spain
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottonotnotbutnotthethehownottobutnotbutbuttonot
# Actual: whatsapp bring back old text status
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttotoununnotevenbutnotununun
# Actual: india incomplete without pak39s sindh province lk advani
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently actually now currently also now currently
# Actual: us withdrawal cause collapse afghanistan russia
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottobutnottotonoteventotothethebutnotthethehownotnotbutnottootototootootoo
# Actual: sartaj azizs visit india disgrace pak hafiz saeed
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: free access research articles 3920 eu
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: 10 members family found dead slit throats
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: microsoft starts shipping surface hub whiteboard
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhenbutbutandandbutbutaccordingaccordingaccordingbutnotevenevenbutbuteveneveneventhethebutnottobutnotyetyetyetnotnoteventhenotnot
# Actual: cong leaders39 supporters vandalise party office u39khand
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: sun pharma q2 net profit rises 117 2235 crore
#
# Prediction:  a a a an an an a a the the the an an ag ag ag ang ang ang ag ag Ag ag ag AG AG AGAGAGAG AGAGagagagAGAGaggaggaggagagaggaggagaragaragargargargarGargargaragaragaragagagaragar
# Actual: vijender alleges bias rio wildcard snub
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: stalkbuylove gets funded 500 startups others
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: germany unveils new laws refugees
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: poet threatens mamata didn39t respond poems
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: india offers cheapest flights world survey
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: spare civilians battle mosul red cross
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: uk pm may39s flight visible tracking app
#
# Prediction: , and other other other many other many many many several several several many many other several several different different different various different different other other various other various various various different various various other different different certain certain certain various various certain certain specific specific specific certain specific certain certain different different specific certain various different specific specific
# Actual: honda plans launch car 5 lakh india
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttonotevenbutnottoonotnotununun
# Actual: militants killed kulgam encounter identified locals
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: microsoft tool describes powerpoint images blind users
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottotonotevenbutnotthethebutnottobutnotbutnottootootootototootoobutbuttoto
# Actual: 39philippines prez killed employee submachine gun39
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottotonoteventotothethebutnottothenottonottobutnotbutnotthethehownotnotbut
# Actual: proposal reservation top courts govt
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnoteveneveneventhethebutnoteventhenotnottotothethenoteventotonotnotthetheyouyouyouyouryouryourmanymanymany
# Actual: vijender accused disrespecting national flag
#
# Prediction: , and other other other many many many thousands thousands thousands millions millions millions billions billions billion billion billion billions billions billions millions billions millions millions million million million millions millions billion billion million million billion billion millions millions thousands millions million millions million billion million millions billions billion billions millions million billions billions million million billions millions billion
# Actual: new 2000 note good indian economy baba ramdev
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenoteventhethebutnottonotevennottothenotnotununnotnotgetgetgetgivegive
# Actual: samsung launches serif tv us
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: wife alleges husband didn39t consult surrogate child
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: 413457 accidental deaths india 2015 ncrb
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: k39taka govt allocates 100 cr setting namma canteens
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttonoteventhethehownotnotthethebut
# Actual: chinese tourist town uses face recognition entry ticket
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttonoteventhethehownotnotthethebut
# Actual: quikr launches realtime car tracking platform
#
# Prediction: , and other other other many other many many many several several many many different different various different different different other other various other other different other various different other different different more more more less less less more more most more more mostly more mostly mostly mostly more most most mostly mostly not not not less more mostly
# Actual: us senator smashes colleague39s 34offensive34 birthday cake
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: absolut vodka uses south korea39s impeachment protests ad
#
# Prediction:  a a a an an an a a to to to and and and to and to to but not not to to not not not NOT NOT NOT not NOT not not unt unt unt nont nont nont antit antit antit multit multit multit subt subt subt multit multit nont nont subt subt antit antit nont nont multit
# Actual: simone 1st afroamerican lady win swimming gold
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: 39angel39 singer taher shah leaves pakistan post death threats
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: painless microneedle drug monitoring system made
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now also not now currently
# Actual: rocket internet raises 1 billion fund internet startups
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottobutnottotonoteventotothethebutnotthethehownotnotbutnottootototootootoo
# Actual: religious leader sits dharna duped 1 cr
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenoteventhenotnottotonotevennotnoteventotothethebutnottobutnotthethehownotnotbutnottootototootootoo
# Actual: 39math english may optional 10th exams maha39
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotevenevenevennotnottotonotnoteventotothethenotevennottobutnottothenotnotbutbuttotoununnotevenbutnotununun
# Actual: jadeja traditional sword dance bat celebrate 50
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: stone laid octomax unit mathura refinery
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhennotnotififnotnotofifififffffffFFFFFFFfffefefefufufefefffffefefafff
# Actual: delhi govt 34entitled34 lodge fir ril
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: rajinikanth injured shooting 392 . 039
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: jaydev shah first play 100 ranji matches captain
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenottotonotevennotnottobutnotthethebutnottonotnotthenoteventotothetheyouyouyouyouryouyou
# Actual: pictures holi celebrations across india
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandnotnotbutnotbutbutwhenbutbutandandbutbutaccordingaccordingaccordingbutnotevenevenbutbuteveneveneventhethebutnottobutnotyetyetyetnotnotevenyetyettoo
# Actual: lashkaretaiba best ngo pakistan pervez musharraf
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottobutnottotonoteventotothethebutnotthethehownotnotbutnottootototootootoo
# Actual: diabetes may shorten life nine years study
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottotonoteventotothethebutnottothenottonottobutnotbutnotthethehownotnotbut
# Actual: top 10 richest people india
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottotonoteventotothethebutnottothenottonottobutnotbutnotthethehownotnotbut
# Actual: 39jai gangaajal39 trending google today
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently also now currently actually now currently
# Actual: frog wedding organised appease rain god
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnotbutnotandnotnotbutbutwhennotnotevenevenevennotnottotothethenotnotthethebutnottothenotevennottobutnoteventhetheyouyouyou
# Actual: 39din mein .  .  .  jagrata39 song 39freaky ali39
#
# Prediction:  the the thethethethetototobutbutbutnotnotnotandandandbutnoteveneveneventhethenotnoteventhenotevennotnottobutnottotonoteventotothethebutnotthethehownotnotbutnottootototootootoo
# Actual: uk football abuse hotline gets 1700 calls three weeks
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently now currently actually now currently also now currently
# Actual: sachin thanks nation supporting rio athletes
#
# Prediction:  the the thethethethetototobutbutbutnotnotandandandbutnoteveneveneven even even even right right now now now that there is now now also now now not not not even even now now actually now now currently currently currently also now also not now currently actually now
# Actual: us stocks post longest decline since 1980

# %% [markdown]
# ### BLEU Scores

# %%
! pip install evaluate
import evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.22.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.4.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (23.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.8.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2022.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.0

# %%
bleu = evaluate.load("google_bleu")
total_bleu_score = 0
for prediction, actual in zip(predictions, actual_headlines):
    total_bleu_score = total_bleu_score + bleu.compute(predictions=[prediction], references=[actual])['google_bleu']
avg_bleu_score = total_bleu_score/len(predictions)
print(avg_bleu_score)
# Out:
# Downloading builder script:   0%|          | 0.00/8.64k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# 4.347826086956522e-06
